# %% [markdown]
# # 作業 2
#
# 本作業使用 [Kaggle Titanic](https://www.kaggle.com/c/titanic/overview) 所提供的資料，根據鐵達尼號乘客資料預測生還者。
# 我們只使用 `train.csv` 進行生還者預測（只有 `train.csv` 才有答案），而加分題需要額外使用 `test.csv` 並提交至 [Kaggle Titanic](https://www.kaggle.com/c/titanic/overview) 進行評分。
#
# 本作業需要先學習[程式教材](https://github.com/IKMLab/course_material)中的以下部份：
#
# - [jupyter-基本功能](https://github.com/IKMLab/course_material/blob/master/jupyter-%E5%9F%BA%E6%9C%AC%E5%8A%9F%E8%83%BD.ipynb)
# - [python-入門語法](https://github.com/IKMLab/course_material/blob/master/python-%E5%85%A5%E9%96%80%E8%AA%9E%E6%B3%95.ipynb)
# - [numpy-基本功能](https://github.com/IKMLab/course_material/blob/master/numpy-%E5%9F%BA%E6%9C%AC%E5%8A%9F%E8%83%BD.ipynb)
# - [pandas-基本功能](https://github.com/IKMLab/course_material/blob/master/pandas-%E5%9F%BA%E6%9C%AC%E5%8A%9F%E8%83%BD.ipynb)
# - [matplotlib-資料視覺化](https://github.com/IKMLab/course_material/blob/master/matplotlib-%E8%B3%87%E6%96%99%E8%A6%96%E8%A6%BA%E5%8C%96.ipynb)
# - [scikit-learn-基本功能](https://github.com/IKMLab/course_material/blob/master/scikit-learn-%E5%9F%BA%E6%9C%AC%E5%8A%9F%E8%83%BD.ipynb)

# %% [markdown]
# ## 繳交規則
#
# 1. 請將**當前資料夾**命名為 `FDA_HW2_你的學號`
#     - 例如：`FDA_HW2_F12345678`
#     - 所有**英文**都必須**大寫**
#     - 所有**文字**都必須在 **ASCII** 範圍
# 2. 請將本檔案命名為 `main.ipynb`
# 3. 請描述開發所需要的**環境**，包含：
#     - **作業系統**與**發行版本**
#         - 例如：Windows、Mac、Linux 等
#         - 需要填寫系統**名稱**與**版本**
#     - **程式執行環境**
#         - 例如：jupyter、kaggle kernel、colab 等
#         - 如果是 jupyter 請**填寫**版本
#         - 如果是雲端計算資源**不需填寫**版本
#         - 請**勿**使用**付費**資源，助教薪水**微薄**
#     - **python 版本**
#         - 例如：3.6.9
#         - 填寫**至少**能執行的版本即可
#     - **安裝環境**
#         - 例如使用 `pip`、`conda` 等
#         - 助教會以虛擬環境測試
#     - **安裝套件**與**版本**
#         - 請使用 `requirements.txt`
#         - 助教會以虛擬環境測試
#         - 請**不要**附上**多餘**的套件
#     - **計算資源**
#         - 使用 CPU **數量**
#         - GPU 版本
#     - **執行**所需花費**時間**
#         - 請**不要更改**擁有註解 `請勿更動此區塊程式碼` 的程式碼區塊
# 4. 請**保留執行結果**讓助教可以直接觀看
#     - 請記得使用 **Save**
#     - **雲端**計算資源請**儲存**後**下載**檔案
#     - 所有程式區塊**必須依序執行**
#     - 請**不要**保留**多餘**的程式區塊
# 5. 請**控制隨機亂數**讓實驗結果可以**重現**
#     - 關鍵字：**random seed**
# 6. 請**不要**上傳**多餘**的檔案
#     - 不要上傳**資料**檔案，包含 `train.csv` 與 `test.csv` 等
#     - 不要上傳**隱藏**檔案，包含 `.git`、`.ipynb_checkpoints` 等
#     - 不要上傳**虛擬環境**
# 7. 請附上**參考連結**
#     - 可以參考公開的 kernel
#     - 沒附上連結者視同**瓢竊**
#     - 使用的**演算法**請附上來源，並大致描述概念
# 8. 請**壓縮**成 `zip` 並上傳至 [moodle](http://moodle.ncku.edu.tw/)
#     - 例如 `FDA_HW2_F12345678.zip`

# %% [markdown]
# ## 評分標準
#
# 如果有參考其他作法卻沒有附上來源，則直接視為瓢竊，得分為 $-\infty$。
#
# |規則|滿足規則得分|沒滿足規則失分|
# |-|-|-|
# |資料夾名稱符合繳交規則|0|-60|
# |檔案名稱符合繳交規則|0|-60|
# |填寫環境需求|0|-60|
# |填寫計算資源|0|-60|
# |提供 `requirements.txt`|0|-60|
# |將資料夾壓縮成 `zip`|0|-60|
# |不更改擁有註解 `請勿更動此區塊程式碼` 的程式碼區塊|0|-60|
# |計算並顯示執行時間|0|-60|
# |控制隨機亂數讓實驗結果可以重現|0|-60|
# |使用 `markdown` 區塊描述資料分析內容|+3|-10|
# |以資料視覺化輔助資料分析並以 `markdown` 區塊輔助描述圖中資訊|+7|-10|
# |選擇使用 `Sex` 與 `Age` 以外的特徵作為輸入並以 `markdown` 區塊描述方法與理由|+5|-10|
# |處理缺失值並以 `markdown` 區塊描述方法與理由|+5|-10|
# |轉換數值資料並以 `markdown` 區塊描述方法與理由|+5|-10|
# |轉換類別資料並以 `markdown` 區塊描述方法與理由|+5|-10|
# |使用其他方法進行資料前處理並以 `markdown` 區塊描述理由|+10|0|
# |使用決策樹以外的模型進行實驗|+10|-10|
# |使用 `markdown` 區塊簡單解釋模型演算法|+10|0|
# |解釋模型超參數的選擇理由|+5|-10|
# |使用 5-fold cross validation 輸出平均準確度|+5|-10|
# |使用所有資料訓練模型並輸出準確度|+5|-10|
# |使用多個不同模型進行實驗|+10|0|
# |使用 ensemble 進行實驗|+10|0|
# |試著讓其中一個實驗模型 overfitting（訓練與驗證準確度差距 > $10\%$）|+9|0|
# |試著讓其中一個實驗模型 underfitting（訓練準確度約 $50\% \pm 10\%$）|+1|0|
# |準確度超越課堂範例（$81\%$）|+10|-10|
# |將最佳實驗結果套用到 `test.csv` 並截圖 Kaggle 評分|+10|0|
# |將最佳實驗結果套用到 `test.csv` 並取得 Kaggle Public Leaderboard Top $10\%$|+20|0|
# |將最佳實驗結果套用到 `test.csv` 並取得 Kaggle Public Leaderboard Top $5\%$|+30|0|
# |將最佳實驗結果套用到 `test.csv` 並取得 Kaggle Public Leaderboard Top $1\%$|+50|0|

# %% [markdown]
# ## 環境
#
# 請填寫當前執行使用的環境。
#
# |環境|名稱|版本|
# |-|-|-|
# |作業系統|Ubuntu|18.04.4 LTS|
# |程式執行環境|jupyter notebook|6.0.3|
# |python 版本|python3|3.6.9|
# |安裝環境|pip|20.0.2|

# %% [markdown]
# ## 安裝
#
# 請填寫安裝套件需要的指令
#
# ```sh
# pip3 install -r requirements.txt
# ```

# %% [markdown]
# ## 計算資源
#
# 請填寫執行程式所需要的計算資源，請確保所有資源限制在單一個人桌上型電腦且能夠以總市價低於 5 萬的手段取得。
#
# |計算資源|答案|
# |-|-|
# |使用 CPU 核心數|12|
# |記憶體需求|242.7MB|
# |有無使用 GPU|無|
# |GPU 版本|無|
# |GPU 記憶體需求|$\leq 1$GB|

# %% [markdown]
# ## 參考連結
#
# - 有無參考他人之實驗結果：無
# - 參考連結：

# %%
# 請勿更動此區塊程式碼

import time
import numpy as np
import pandas as pd

EXECUTION_START_TIME = time.time() # 計算執行時間

df = pd.read_csv('train.csv')      # 讀取資料，請勿更改路徑

# %% [markdown]
# ## 資料分析與前處理
#
# 請在此區塊後使用**一個或多個區塊**進行資料分析與前處理，項目可以包含：
#
# - 資料視覺化
# - 相關係數
# - 決定輸入特徵
# - 處理缺失值
# - 轉換數值
# - 轉換類別
# - 其他
#
# 請以 `markdown` 簡單描述**流程**、**方法**與**原因**：
#
# 1. 觀察...，發現...
# 2. 填補...，策略...
# 3. 轉換...，原因...

# %% [markdown]
# ### 處理缺失值
# * 先用**info**看哪些欄位有缺失值
#     * **Age**缺177個
#     * **Cabin**缺687個
#     * **Embarked**缺了2個
# * **Age**:
#     * 覺得缺失數量尚可接受, 怕統一填補的話會影響訓練出來的準確度, 所以決定直接捨棄掉有缺失Age的樣本
#     * 後來觀察相關係數時發現Age和Pclass的相關係數滿高的, 有嘗試用所屬Pclass的Age中位數來填補缺失值
#     * 但是實驗後發現填補後的準確度比直接捨棄掉還低, 所以最終還是選擇把有缺失Age的樣本從訓練資料裡去除掉
# * **Cabin**:
#     缺失率高達77%, 如果統一填補怕會誤導結果, 如果把有缺失的都捨棄掉又會導致訓練資料太少, 所以決定放棄用這個feature訓練
# * **Embarked**:
#     只缺2個, 因為屬於類別資料, 所以決定用眾數填補

# %%
# 處理缺失值
from sklearn.impute import SimpleImputer
print(df.info())
print()
# 填補'Embarked'缺失值(用眾數)
imputer = SimpleImputer(strategy='most_frequent')
df['Embarked'] = imputer.fit_transform(df['Embarked'].to_numpy().reshape(-1, 1))

# 填補'Age'缺失值（用所屬Pclass的Age中位數）
# age_by_pclass_sex = df.groupby(['Pclass']).median()['Age']
# df['Age'] = df.groupby(['Pclass'])['Age'].apply(lambda x: x.fillna(x.median()))
# print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %% [markdown]
# ### 轉換類別資料
# * 先試用  **Label Encoder**  把**Sex**和**Embarked**資料轉換成數字
#     * **Sex**
#         * 0:male
#         * 1:female
#     * **Embarked**
#         * 0:C
#         * 1:Q
#         * 2:S
# * 因為後來視覺化後發現兩個類別剛好都是數字越大死亡率越高, 所以決定選擇用  **Label Encoder**  就好, 沒有改用**One-hot Encoder**

# %%
# 轉換類別資料
from sklearn.preprocessing import LabelEncoder
## 轉換Sex資料(0:male, 1:female)
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
## 轉換Embarked資料(0:C, 1:Q, 2:S)
le = LabelEncoder()
df['Embarked'] = le.fit_transform(df['Embarked'])

# %% [markdown]
# ### 資料視覺化
# #### 畫長條圖觀察Survived與Pclass的關係
# * 從圖中發現**Pclass**數字越小（ticket class越高階）, 存活率越高, 可能是ticket class越高階的座位相對比較安全或是可先獲救
# * 推測**Pclass**跟存活率可能存在一定關係
# ![Imgur](https://i.imgur.com/nm4xA1r.png)
#
# #### 畫長條圖觀察Survived與Sex的關係
# * 從圖中發現男性的存活率比女性高非常多
# * 推測**Sex**跟存活率可能存在一定關係
# ![Imgur](https://i.imgur.com/QqBlCNV.png)
#
# #### 畫長條圖觀察Survived與Embarked的關係
# * 從圖中發現從Cherbourg登船的存活率明顯比從Southampton登船高很多
# * 推測**Embraked**跟存活率或許也存在一定關係
# ![Imgur](https://i.imgur.com/x0q7LRd.png)
#
# #### 畫散布圖和盒狀圖觀察Survived與Age的關係
# * 從散布圖看不太出來存活與死亡的年齡分佈有什麼明顯差距
# * 從盒狀圖可看到死者的主要年齡分佈比起生還者的主要年齡分佈有稍高一點, 但差距還是沒有很明顯
# ![Imgur](https://i.imgur.com/TB1UKUH.png)
#
# #### 畫散布圖和盒狀圖觀察Survived與Fare的關係
# * 散布圖中因為有離群值的關係, 所以主要分佈的地方被壓縮得太密集, 看不太出來兩邊的分佈差距
# * 盒狀圖就可看出生還者的普遍Fare有較高
# ![Imgur](https://i.imgur.com/4BEUilM.png)

# %%
# 以資料視覺化輔助資料分析
import matplotlib.pyplot as plt
import seaborn as sns

# 算同時符合feature A和feature B的乘客數
def countNum(colA, valA, colB, valB):
  return df[(df[colA] ==valA) & (df[colB] ==valB)].PassengerId.count()

# 在每個長條上標記人數
def autoLabel(rects, ax):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

# 畫出feature各類別的存活/死亡人數長條圖       
def drawChart(labels, dead, survived, xLabel):
  x = np.arange(len(labels))
  width = 0.35

  fig, ax = plt.subplots()
  rects1 = ax.bar(x - width/2, dead, width, label='Not Survived')
  rects2 = ax.bar(x + width/2, survived, width, label='Survived')

  ax.set_xlabel(xLabel)
  ax.set_ylabel('Number of passengers')
  ax.set_xticks(x)
  ax.set_xticklabels(labels)
  ax.legend()

  autoLabel(rects1, ax)
  autoLabel(rects2, ax)

  fig.tight_layout()
  plt.show()
  print()

# 畫長條圖觀察Survived與Pclass的關係
labels = ['1', '2', '3']
survived = [countNum('Survived', 1, 'Pclass', 1), countNum('Survived', 1, 'Pclass', 2), countNum('Survived', 1, 'Pclass', 3)]
dead = [countNum('Survived', 0, 'Pclass', 1), countNum('Survived', 0, 'Pclass', 2), countNum('Survived', 0, 'Pclass', 3)]
drawChart(labels, dead, survived,'Pclass')

# 畫長條圖觀察Survived與Sex的關係
labels = ['male', 'female']
survived = [countNum('Survived', 1, 'Sex', 0), countNum('Survived', 1, 'Sex', 1)]
dead = [countNum('Survived', 0, 'Sex', 0), countNum('Survived', 0, 'Sex', 1)]
drawChart(labels, dead, survived, 'Sex')

# 畫長條圖觀察Survived與Embarked的關係
labels = ['C', 'Q', 'S']
survived = [countNum('Survived', 1, 'Embarked', 0), countNum('Survived', 1, 'Embarked', 1), countNum('Survived', 1, 'Embarked', 2)]
dead = [countNum('Survived', 0, 'Embarked', 0), countNum('Survived', 0, 'Embarked', 1), countNum('Survived', 0, 'Embarked', 2)]
drawChart(labels, dead, survived, 'Embarked')

# 畫散布圖和盒狀圖觀察Survived與Age的關係
ax = sns.boxplot(x="Survived", y="Age", data=df, whis=np.inf)
ax = sns.stripplot(x="Survived", y="Age", data=df, color="0", jitter=0.15)
plt.show()
print()

# 畫散布圖和盒狀圖觀察Survived與Fare的關係
ax = sns.boxplot(x='Survived', y='Fare', data=df, whis=np.inf)
ax = sns.stripplot(x='Survived', y='Fare', data=df, color='0', jitter=0.15)
plt.show()
print()

# %% [markdown]
# ### 使用其他方法進行資料前處理： 去除離群值
# 上面的散布圖因為有離群值的關係, 所以樣本點集中的地方太擠, 看不太出來兩邊差異
# 因此嘗試去除**Age**及**Fare**的離群值之後再觀察一次

# %%
# 去除離群值並再畫一次散布圖
def removeOutlier(feature):
  q1 = df[feature].describe()['25%']
  q3 = df[feature].describe()['75%']
  low = q1 - 1.5 * (q3 - q1)
  high = q3 + 1.5 * (q3 - q1)
  tmp = df[(df[feature] >= low) & (df[feature] <= high)]
  ax = sns.boxplot(x="Survived", y=feature, data=tmp, whis=np.inf)
  ax = sns.stripplot(x='Survived', y=feature, data=tmp, color='0', jitter=0.15)
  plt.show()
  print()


removeOutlier('Age')
removeOutlier('Fare')

# %% [markdown]
# ### 把數值範圍切成區段, 以區段分類畫成長條圖
# 為了更詳細觀察**Age**、**Fare**分別與存活率之間的關係, 把數值以所屬區段分類後再畫成長條圖
# * 用**qcut**把**Age**的數值範圍切成10個區間, 並畫成長條圖觀察存活率的變化
#     * (0, 14] 的存活率明顯比其他區段高很多
#     * (31, 36] 的存活率也較其他區段稍高
# * 用**qcut**把**Fare**的數值範圍切成15個區間, 並畫成長條圖觀察存活率的變化
#     * 10.5以下的存活率非常低
#     * 39.688以上的存活率較高

# %%
# 畫成長條圖
def drawIntervalBar(data, feature, x_labelSize):
  data_drop = data[data[feature]!='nan']
  fig, axs = plt.subplots(figsize=(22, 9))
  sns.countplot(x=feature, hue='Survived', data=data_drop)
  plt.xlabel(feature, size=15, labelpad=20)
  plt.ylabel('Passenger Count', size=15, labelpad=20)
  plt.tick_params(axis='x', labelsize=x_labelSize)
  plt.tick_params(axis='y', labelsize=15)
  plt.legend(['Not Survived', 'Survived'], loc='upper right', prop={'size': 15})
  plt.title('Survival Counts in {} Feature'.format(feature), size=15, y=1.05)
  plt.show()
  print()

# 把數值以區間分類
def classifyNum(data, feature, cut, x_labelSize):
  data[feature] = pd.qcut(data[feature], cut) # 先切成10個區段
  drawIntervalBar(data, feature, x_labelSize)
  le = LabelEncoder()
  data[feature] = le.fit_transform(data[feature].astype(str)) # 把區段編號

    
df_v2 = df.copy()
classifyNum(df_v2, 'Age', 10, 15)
classifyNum(df_v2, 'Fare', 15, 10)

# %% [markdown]
# ### 轉換數值資料
# 用**describe**可看到**Fare**欄位的最大值是512, 最小值是0
# 差距超過$10^2$
# 所以使用 **StandardScaler** 將**Fare**數值資料標準化
# 算法為: 新值 = (原值 - 平均數) / 標準差

# %%
# 轉換數值資料
from sklearn.preprocessing import StandardScaler
print('標準化前： ')
print(df['Fare'].describe())
values = df['Fare'].to_numpy().reshape(-1, 1)
normalizer = StandardScaler()
normalizer.fit(values)
df['Fare'] = normalizer.transform(values)
print()
print('標準化後： ')
print(df['Fare'].describe())
# Out:
# 標準化前：
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64
#
# 標準化後：
# count    8.910000e+02
# mean     3.987333e-18
# std      1.000562e+00
# min     -6.484217e-01
# 25%     -4.891482e-01
# 50%     -3.573909e-01
# 75%     -2.424635e-02
# max      9.667167e+00
# Name: Fare, dtype: float64

# %% [markdown]
# ### 相關係數
# * 觀察Survived分別與其他各feature之間的相關係數
#     * 與Survived間相關性較高的feature有:
#         * Sex
#         * Pclass
#         * Fare
# * 觀察任兩個features之間的相關係數
#     * 兩兩間相關性較高的有:
#       * Fare & Pclass
#       * Sex & Survived
#       * Parch & SibSp
#       * Age & Pclass
#       * Pclass & Survived

# %%
# 相關係數
# 觀察Survived分別與其他各feature之間的相關係數
print('Correlation coefficient between "Survived" and other features: ')
print(df.corr()['Survived'])
print()
# 觀察任兩個features之間的相關係數
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation coefficient between two features')
plt.show()
# Out:
# Correlation coefficient between "Survived" and other features:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Sex           -0.543351
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Embarked      -0.167675
# Name: Survived, dtype: float64

# %% [markdown]
# ## 模型訓練
#
# 請在此區塊後使用**一個或多個區塊**進行模型訓練，**需要**包含以下內容：
#
# - **選擇模型**
#     - 設定模型**超參數**
#     - **控制隨機亂數**
# - 計算**準確度（Accuracy）**
#     - 使用 **5-fold cross validation**，輸出**平均準確度**
#     - 最後再使用**所有**資料進行訓練並輸出**準確度**
#     - 準確度必須**超越**課堂使用的範例
#
# 如果有進行多於一個以上的實驗，**可以保留所有**的實驗結果，但是執行時間將會納入**全部**實驗。

# %% [markdown]
# ### 自定義的 *cross_and_all()*  function
# * 先使用 **5-fold cross validation** 輸出平均準確度
# * 最後再使用所有資料訓練模型並輸出準確度

# %%
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
SEED = 42 # 控制隨機亂數

# 先使用 5-fold cross validation, 再使用所有資料進行訓練並輸出準確度
def cross_and_all(model, train_x):  
  kf = KFold(n_splits=5,
            random_state=1012,
            shuffle=True)
  kf.get_n_splits(train_x)

  train_acc_list = []
  valid_acc_list = [] 

  # 5-fold cross validation
  for train_index, valid_index in kf.split(train_x):
      train_x_split = train_x.iloc[train_index]
      train_y_split = train_y.iloc[train_index]
      valid_x_split = train_x.iloc[valid_index]
      valid_y_split = train_y.iloc[valid_index]
    
      model.fit(train_x_split, train_y_split)
    
      train_pred_y = model.predict(train_x_split)
      train_acc = accuracy_score(train_y_split,
                               train_pred_y)
      valid_pred_y = model.predict(valid_x_split)
      valid_acc = accuracy_score(valid_y_split,
                               valid_pred_y)
    
      train_acc_list.append(train_acc)
      valid_acc_list.append(valid_acc)

  print((
      'average train accuracy: {}\n' +
      '    min train accuracy: {}\n' +
      '    max train accuracy: {}\n' +
      'average valid accuracy: {}\n' +
      '    min valid accuracy: {}\n' +
      '    max valid accuracy: {}').format(
      np.mean(train_acc_list),
      np.min(train_acc_list),
      np.max(train_acc_list),
      np.mean(valid_acc_list),
      np.min(valid_acc_list),
      np.max(valid_acc_list)
  ))

  # 用所有資料進行訓練
  model.fit(train_x, train_y)
  pred_y = model.predict(train_x)
  acc = accuracy_score(train_y, pred_y)
  print('accuracy: {}\n'.format(acc))

# %% [markdown]
# ### 選擇使用 Sex 與 Age 以外的特徵作為輸入
# 由先前的資料視覺化結果以及觀察相關係數,
# 發現除了**Sex**以外,
# **Pclass**、**Fare**、**Embarked**是與**Survived**較有相關性的feature
# 所以本來是先嘗試加入以上3個feature作為輸入特徵
# 這3個feature中相關係數最小的是**Embarked**
# 所以後來又嘗試把**Embarked**從輸入特徵中拿掉
# 實驗後發現拿掉**Embarked**的準確率會較高
# 因此最終選擇只多加 **Pclass** 和 **Fare** 作為輸入特徵

# %%
# 訓練的資料
df_drop = df.dropna(axis=0, subset=['Age']) # 去除有缺失'Age'的資料
train_y = df_drop['Survived']
train_x1 = df_drop[['Sex', 'Age']]
train_x2 = df_drop[['Sex', 'Age', 'Pclass', 'Fare']]  # 使用 Sex 與 Age 以外的特徵作為輸入

# %% [markdown]
# ### DecisionTreeClassifier的超參數
# * **criterion**:
#     因為其他參數都相同的情況下, 用**gini**的準確度會比用**entropy**高
# * **max_depth**:
#     * 深度越深, 準確度越高, 但是也更會overfitting
#     * max_depth = 3時, 準確度僅81%
#     * max_depth = 4以上, 準確度就可以超越81%
#     * 但是max_depth=5時, 訓練和驗證的準確度會差到6%, 所以選擇max_depth=4就好

# %%
# 準確度超越課堂範例（81%)
dTree_model = DecisionTreeClassifier(
    criterion='gini',
    max_depth=4,
    max_leaf_nodes=4 ** 2,
    random_state=SEED)
cross_and_all(dTree_model, train_x2)
# Out:
# average train accuracy: 0.8368345314930254
#     min train accuracy: 0.8266199649737302
#     max train accuracy: 0.8458844133099825
# average valid accuracy: 0.7969565645621983
#     min valid accuracy: 0.7552447552447552
#     max valid accuracy: 0.8531468531468531
# accuracy: 0.8305322128851541

# %% [markdown]
# ### 使用 ensemble 進行實驗
# 使用**Random Forest Classifier**模型
#    * **n_estimators**:
#         * 代表決策樹的個數, 越多可提高準確率, 但是performance較差
#         * 經過調整後, 891~900間準確率最高, 小於或大於都會使準確率變低
#    * **max_depth**:
#        * 代表樹的最大深度
#        * 經過調整後, 7的準確率最高, 小於或大於都會使準確率變低
#    * **min_samples_split**:
#        * 代表根據屬性劃分節點時，每個劃分最少的樣本數
#        * 太大時準確率會降低, 所以選擇3
#    * **min_samples_leaf**:
#        * 葉子節點最少的樣本數
#        * 越小準確度會越高, 但是也越會overfitting, 6是在準確度和overfitting間的折衷選擇

# %%
# 使用 ensemble 進行實驗
from sklearn.ensemble import RandomForestClassifier

randForest_model = RandomForestClassifier(criterion='gini',
                                           n_estimators=891,
                                           max_depth=7,
                                           min_samples_split=3,
                                           min_samples_leaf=6,
                                           max_features='auto',
                                           bootstrap=True,
                                           oob_score=True,
                                           random_state=SEED,
                                           n_jobs=-1,
                                           verbose=0)
cross_and_all(randForest_model, train_x2)
# Out:
# average train accuracy: 0.872548467294527
#     min train accuracy: 0.8651488616462347
#     max train accuracy: 0.8809106830122592
# average valid accuracy: 0.8123608785580616
#     min valid accuracy: 0.7482517482517482
#     max valid accuracy: 0.8461538461538461
# accuracy: 0.8795518207282913

# %% [markdown]
# ### 試著讓其中一個實驗模型 overfitting
# * 超參數:
#     * **n_estimators**: 因為只是要overfitting, 所以選擇官方預設範圍(10~100)的最小值10, 可以較快跑完
#     * **max_depth**: 因為要overfitting, 所以選擇不設max
#     * **min_samples_leaf**: 因為要overfitting, 所以選擇設最小值1
#     * **max_features**: 因為要overfitting, 所以選擇不設max

# %%
# 試著讓其中一個實驗模型 overfitting（訓練與驗證的平均準確度差距 > 10%）
overfit_model = RandomForestClassifier(criterion='gini', 
                                           n_estimators=10,
                                           max_depth=None,
                                           min_samples_split=3,
                                           min_samples_leaf=1,
                                           max_features=None,
                                           bootstrap=False,
                                           oob_score=False,
                                           random_state=SEED,
                                           n_jobs=-1,
                                           verbose=0)
train_x3 = df_drop[['Sex', 'Age', 'Pclass', 'Fare', 'Embarked', 'SibSp', 'Parch']]
cross_and_all(overfit_model, train_x3)
# Out:
# average train accuracy: 0.9726893071901829
#     min train accuracy: 0.9667250437828371
#     max train accuracy: 0.9772329246935202
# average valid accuracy: 0.7647099379493746
#     min valid accuracy: 0.7062937062937062
#     max valid accuracy: 0.7972027972027972
# accuracy: 0.9719887955182073

# %% [markdown]
# ### 使用決策樹以外的多個不同模型進行實驗
# * **SVC** (C-Support Vector Classification)
#     * **C**: 錯誤項的懲罰係數, 越大準確率可較高, 但也越會overfitting, 3是準確率與overfitting間的折衷選擇
#     * **kernel**: 選擇SVM最常用也最適合用在這裡的rbf, 其他的linear/poly/sigmoid都不適合用在這裡, 準確率會很低
# * **KNeighborsClassifier** (Classifier implementing the k-nearest neighbors vote)
#     * **n_neighbors**: 超過14之後再提高都不會再讓準確率更高, 所以選擇14
#     * **weights**: 選擇distance function讓越近的neighbor對於所預測的點影響越大
#     * **algorithm**: 選擇auto根據傳進 **fit()** 的值決定最適合的演算法
#     * **p=1**: 選擇用歐幾里得距離
# * **GaussianNB** (Gaussian Naive Bayes)
#     * **priors**: 不指定讓模型根據資料自己計算

# %%
# 使用決策樹以外的模型進行實驗
# 使用多個不同模型進行實驗
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

svc_model = SVC(C=3,
                kernel='linear', 
                gamma='auto', 
                probability= True,
                random_state=SEED,
                decision_function_shape='ovr')
cross_and_all(svc_model, train_x1)

knn_model = KNeighborsClassifier(n_neighbors = 14, 
                                       weights='distance', 
                                       algorithm='auto', 
                                       p=2,
                                       n_jobs=-1)
cross_and_all(knn_model, train_x1)

gaussian_model = GaussianNB(priors=None)
cross_and_all(gaussian_model, train_x1)
# Out:
# average train accuracy: 0.7801170808176063
#     min train accuracy: 0.7657342657342657
#     max train accuracy: 0.7950963222416813
# average valid accuracy: 0.7801930463902296
#     min valid accuracy: 0.7202797202797203
#     max valid accuracy: 0.8380281690140845
# accuracy: 0.7801120448179272
#
# average train accuracy: 0.8287827758931087
#     min train accuracy: 0.8143607705779334
#     max train accuracy: 0.8353765323992994
# average valid accuracy: 0.7409435634787747
#     min valid accuracy: 0.7062937062937062
#     max valid accuracy: 0.7972027972027972
# accuracy: 0.8207282913165266
#
# average train accuracy: 0.7801170808176063
#     min train accuracy: 0.7657342657342657
#     max train accuracy: 0.7950963222416813
# average valid accuracy: 0.7801930463902296
#     min valid accuracy: 0.7202797202797203
#     max valid accuracy: 0.8380281690140845
# accuracy: 0.7801120448179272

# %% [markdown]
# ### 試著讓其中一個實驗模型 underfitting
# 在 SVC model 中把 kernel 設成最不適合用在這裡的 **sigmoid** 即可讓準確度大幅下降

# %%
# 試著讓其中一個實驗模型 underfitting (約59%)
underfit_model = SVC(C=1,
                kernel='sigmoid', 
                gamma='auto', 
                probability= False,
                random_state=SEED,
                decision_function_shape='ovr')
cross_and_all(underfit_model, train_x1)
# Out:
# average train accuracy: 0.593834274307129
#     min train accuracy: 0.5831873905429071
#     max train accuracy: 0.6031468531468531
# average valid accuracy: 0.5937850881512853
#     min valid accuracy: 0.5563380281690141
#     max valid accuracy: 0.6363636363636364
# accuracy: 0.5938375350140056

# %% [markdown]
# ## 加分題
#
# 請將訓練後的模型套用至 [Kaggle Titanic](https://www.kaggle.com/c/titanic/overview) `test.csv` 上，並上傳至 Kaggle 進行評分，**截圖**後**嵌入**至 `markdown` 區塊中。
# ![Imgur](https://i.imgur.com/Q985eHF.png)

# %%
# 請勿更動此區塊程式碼

EXECUTION_END_TIME = time.time() # 計算執行時間
print('total execution time: {}'.format(EXECUTION_END_TIME - EXECUTION_START_TIME))
# Out:
# total execution time: 19.351041555404663
